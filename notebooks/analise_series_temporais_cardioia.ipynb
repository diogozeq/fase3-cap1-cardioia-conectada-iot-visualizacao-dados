# %% [markdown]
# # CardioIA Fase 3 - IA em series temporais de saude
#
# Este notebook compara um classificador tradicional com um modelo neuromorfico simples. Ele continua a Fase 2, que ja havia usado classificacao e metricas de IA, agora aplicando a mesma logica a sinais vitais continuos da Fase 3.

# %% [markdown]
# ## Metodologia
#
# - Gerar janelas temporais simuladas com BPM, temperatura e movimento.
# - Extrair features estatisticas para Logistic Regression.
# - Aplicar um modelo LIF simples que acumula estimulos ao longo do tempo.
# - Comparar acuracia, F1 e matriz de confusao.

# %%
# %run analise_series_temporais_cardioia.py

# %% [markdown]
# ## Analise critica
#
# A Logistic Regression e simples, interpretavel e adequada para features tabulares. O modelo LIF e mais proximo de uma leitura sequencial incremental, interessante para Edge Computing, mas depende de calibracao de limiar e estimulo. Para um produto real, ambos deveriam ser validados com dados reais, acompanhamento clinico e analise de vies, seguindo a preocupacao de governanca iniciada na Fase 1.
